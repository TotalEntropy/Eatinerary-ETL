# %%
# Importing dependencies
import os
import pandas as pd

# %%
# Path to raw dataset not uploaded to github due to size requirement
yelp_business_raw_path = os.path.join('..', 'data', 'yelp_dataset', 'raw', 'business.json')

# %%
# Creating pd dataframe
yelp_business_raw = pd.read_json(yelp_business_raw_path, lines=True)

# %%
yelp_business_raw.count()
# Out:
# address         192609
# attributes      163773
# business_id     192609
# categories      192127
# city            192609
# hours           147779
# is_open         192609
# latitude        192609
# longitude       192609
# name            192609
# postal_code     192609
# review_count    192609
# stars           192609
# state           192609
# dtype: int64

# %%
yelp_business_raw.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# 3                      Insurance, Financial Services     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
#
#     longitude                             name postal_code  review_count  \
# 0 -112.018481       Arizona Biltmore Golf Club       85016             5
# 1  -79.652289       Emerald Chinese Restaurant     L5R 3E7           128
# 2  -80.859132      Musashi Japanese Restaurant       28210           170
# 3 -112.395596  Farmers Insurance - Paul Lorenz       85338             3
# 4  -80.887223              Queen City Plumbing       28217             4
#
#    stars state
# 0    3.0    AZ
# 1    2.5    ON
# 2    4.0    NC
# 3    5.0    AZ
# 4    4.0    NC

# %%
# Select only the businesses in Ontario
yelp_business_ontario = yelp_business_raw.loc[yelp_business_raw['state'] == 'ON']

# %%
yelp_business_ontario.head()
# Out:
#                                               address  \
# 1                                30 Eglinton Avenue W
# 5   Credit Valley Town Plaza, F2 - 6045 Creditview Rd
# 15                                   1455 16th Avenue
# 19                       445 King Street W, Suite 101
# 26                        865 York Mills Road, Unit 1
#
#                                            attributes             business_id  \
# 1   {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 5   {'BusinessParking': '{'garage': False, 'street...  68dUKd8_8liJ7in4aWOSEA
# 15  {'ByAppointmentOnly': 'False', 'BikeParking': ...  A98xW4qb7vOTguggHFs7Ng
# 19  {'AcceptsInsurance': 'True', 'ByAppointmentOnl...  zSpQmEBvRe3IhTUlMSA6HQ
# 26  {'RestaurantsDelivery': 'False', 'RestaurantsP...  C9oCPomVP0mtKa8z99E3gg
#
#                                            categories           city  \
# 1   Specialty Food, Restaurants, Dim Sum, Imported...    Mississauga
# 5   Shipping Centers, Couriers & Delivery Services...    Mississauga
# 15           Fitness & Instruction, Active Life, Yoga  Richmond Hill
# 19  Trainers, Health & Medical, Active Life, Physi...        Toronto
# 26                                     Bakeries, Food        Toronto
#
#                                                 hours  is_open   latitude  \
# 1   {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 5   {'Monday': '9:0-19:0', 'Tuesday': '9:0-20:0', ...        1  43.599475
# 15  {'Monday': '16:0-23:0', 'Tuesday': '16:0-23:0'...        1  43.861503
# 19  {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1  43.645041
# 26  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...        1  43.754093
#
#     longitude                        name postal_code  review_count  stars  \
# 1  -79.652289  Emerald Chinese Restaurant     L5R 3E7           128    2.5
# 5  -79.711584               The UPS Store     L5V 0B1             3    2.5
# 15 -79.388499           Hot Yoga Wellness     L4B 3G6             4    4.0
# 19 -79.395799          Totum Life Science     M5V 1K4            23    4.0
# 26 -79.349548               Bakery Gateau     M3B 1Y6             8    4.5
#
#    state
# 1     ON
# 5     ON
# 15    ON
# 19    ON
# 26    ON

# %%
yelp_business_ontario.count()
# Out:
# address         33412
# attributes      27874
# business_id     33412
# categories      33342
# city            33412
# hours           24299
# is_open         33412
# latitude        33412
# longitude       33412
# name            33412
# postal_code     33412
# review_count    33412
# stars           33412
# state           33412
# dtype: int64

# %%
# Dropping any rows with blank values in these categories
yelp_business_ontario_clean = yelp_business_ontario.dropna(subset=['name', 'address', 'postal_code', 'city', 'state', 'latitude', 'longitude', 'attributes',
                                                          'categories']).reset_index()

# %%
yelp_business_ontario_clean.count()
# Out:
# index           27874
# address         27874
# attributes      27874
# business_id     27874
# categories      27874
# city            27874
# hours           20822
# is_open         27874
# latitude        27874
# longitude       27874
# name            27874
# postal_code     27874
# review_count    27874
# stars           27874
# state           27874
# dtype: int64

# %%
# Selecting all of the restaurants
yelp_restaurants_ontario = yelp_business_ontario_clean[yelp_business_ontario_clean['categories'].str.contains('Restaurants')].reset_index()

# %%
yelp_restaurants_ontario.count()
# Out:
# level_0         14142
# index           14142
# address         14142
# attributes      14142
# business_id     14142
# categories      14142
# city            14142
# hours           10717
# is_open         14142
# latitude        14142
# longitude       14142
# name            14142
# postal_code     14142
# review_count    14142
# stars           14142
# state           14142
# dtype: int64

# %%
yelp_restaurants_ontario.head()
# Out:
#    level_0  index                      address  \
# 0        0      1         30 Eglinton Avenue W
# 1        6     29          1170 Queen Street W
# 2        7     32          1051 Bloor Street W
# 3        8     50           582 College Street
# 4        9     61  17205 Leslie Street, Unit 2
#
#                                           attributes             business_id  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 1  {'WiFi': 'u'no'', 'BikeParking': 'True', 'Rest...  NDuUMJfrWk52RA-H-OtrpA
# 2  {'BusinessParking': '{'garage': False, 'street...  SP_YXIEwkFPPl_9anCYmpQ
# 3  {'Alcohol': 'u'full_bar'', 'Caters': 'False', ...  mlHC2XcU9Bows6cnYEmRgg
# 4  {'RestaurantsAttire': ''casual'', 'Restaurants...  6l00a9Gkxkcp_y-GPjYBiw
#
#                                           categories         city  \
# 0  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 1  Juice Bars & Smoothies, Food, Restaurants, Fas...      Toronto
# 2  Restaurants, Nightlife, Breakfast & Brunch, Ve...      Toronto
# 3  Restaurants, Breakfast & Brunch, Bars, Modern ...      Toronto
# 4                          Fish & Chips, Restaurants    Newmarket
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 1  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...        1  43.642889
# 2  {'Tuesday': '9:0-18:0', 'Wednesday': '9:0-18:0...        0  43.660494
# 3  {'Thursday': '18:0-2:0', 'Friday': '18:0-2:0',...        0  43.655420
# 4                                               None        1  44.058765
#
#    longitude                        name postal_code  review_count  stars  \
# 0 -79.652289  Emerald Chinese Restaurant     L5R 3E7           128    2.5
# 1 -79.425429              Bolt Fresh Bar     M6J 1J5            57    3.0
# 2 -79.432099       The Steady Cafe & Bar     M6H 1M4            29    3.5
# 3 -79.413352          Mad Crush Wine Bar     M6G 1B3             9    4.0
# 4 -79.429115            J's Fish & Chips     L3Y 8Y8            12    4.5
#
#   state
# 0    ON
# 1    ON
# 2    ON
# 3    ON
# 4    ON

# %%
yelp_restaurants_ontario['City Lowercase'] = yelp_restaurants_ontario['city'].str.lower()

# %%
# Only taking these columns
yelp_restaurants_ontario_clean = yelp_restaurants_ontario.loc[:, ['name', 'address', 'postal_code', 'city', 'City Lowercase', 'state', 'latitude', 'longitude',
                                                                  'attributes', 'categories', 'stars', 'hours']]

# %%
yelp_restaurants_ontario_clean.head()
# Out:
#                          name                      address postal_code  \
# 0  Emerald Chinese Restaurant         30 Eglinton Avenue W     L5R 3E7
# 1              Bolt Fresh Bar          1170 Queen Street W     M6J 1J5
# 2       The Steady Cafe & Bar          1051 Bloor Street W     M6H 1M4
# 3          Mad Crush Wine Bar           582 College Street     M6G 1B3
# 4            J's Fish & Chips  17205 Leslie Street, Unit 2     L3Y 8Y8
#
#           city City Lowercase state   latitude  longitude  \
# 0  Mississauga    mississauga    ON  43.605499 -79.652289
# 1      Toronto        toronto    ON  43.642889 -79.425429
# 2      Toronto        toronto    ON  43.660494 -79.432099
# 3      Toronto        toronto    ON  43.655420 -79.413352
# 4    Newmarket      newmarket    ON  44.058765 -79.429115
#
#                                           attributes  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...
# 1  {'WiFi': 'u'no'', 'BikeParking': 'True', 'Rest...
# 2  {'BusinessParking': '{'garage': False, 'street...
# 3  {'Alcohol': 'u'full_bar'', 'Caters': 'False', ...
# 4  {'RestaurantsAttire': ''casual'', 'Restaurants...
#
#                                           categories  stars  \
# 0  Specialty Food, Restaurants, Dim Sum, Imported...    2.5
# 1  Juice Bars & Smoothies, Food, Restaurants, Fas...    3.0
# 2  Restaurants, Nightlife, Breakfast & Brunch, Ve...    3.5
# 3  Restaurants, Breakfast & Brunch, Bars, Modern ...    4.0
# 4                          Fish & Chips, Restaurants    4.5
#
#                                                hours
# 0  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 1  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# 2  {'Tuesday': '9:0-18:0', 'Wednesday': '9:0-18:0...
# 3  {'Thursday': '18:0-2:0', 'Friday': '18:0-2:0',...
# 4                                               None

# %%
# Renaming the columns
yelp_restaurants_ontario_clean.columns
yelp_restaurants_ontario_clean.columns = ['Name', 'Address', 'Postal code', 'City', 'City Lowercase', 'Province', 'Latitude', 'Longitude',
       'Attributes', 'Categories', 'Stars', 'Hours']

# %%
yelp_restaurants_ontario_clean.head()
# Out:
#                          Name                      Address Postal code  \
# 0  Emerald Chinese Restaurant         30 Eglinton Avenue W     L5R 3E7
# 1              Bolt Fresh Bar          1170 Queen Street W     M6J 1J5
# 2       The Steady Cafe & Bar          1051 Bloor Street W     M6H 1M4
# 3          Mad Crush Wine Bar           582 College Street     M6G 1B3
# 4            J's Fish & Chips  17205 Leslie Street, Unit 2     L3Y 8Y8
#
#           City City Lowercase Province   Latitude  Longitude  \
# 0  Mississauga    mississauga       ON  43.605499 -79.652289
# 1      Toronto        toronto       ON  43.642889 -79.425429
# 2      Toronto        toronto       ON  43.660494 -79.432099
# 3      Toronto        toronto       ON  43.655420 -79.413352
# 4    Newmarket      newmarket       ON  44.058765 -79.429115
#
#                                           Attributes  \
# 0  {'RestaurantsReservations': 'True', 'GoodForMe...
# 1  {'WiFi': 'u'no'', 'BikeParking': 'True', 'Rest...
# 2  {'BusinessParking': '{'garage': False, 'street...
# 3  {'Alcohol': 'u'full_bar'', 'Caters': 'False', ...
# 4  {'RestaurantsAttire': ''casual'', 'Restaurants...
#
#                                           Categories  Stars  \
# 0  Specialty Food, Restaurants, Dim Sum, Imported...    2.5
# 1  Juice Bars & Smoothies, Food, Restaurants, Fas...    3.0
# 2  Restaurants, Nightlife, Breakfast & Brunch, Ve...    3.5
# 3  Restaurants, Breakfast & Brunch, Bars, Modern ...    4.0
# 4                          Fish & Chips, Restaurants    4.5
#
#                                                Hours
# 0  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 1  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# 2  {'Tuesday': '9:0-18:0', 'Wednesday': '9:0-18:0...
# 3  {'Thursday': '18:0-2:0', 'Friday': '18:0-2:0',...
# 4                                               None

# %%
#yelp_restaurants_ontario_clean.dtypes

# %%
yelp_restaurants_ontario_clean.City.unique()
# Out:
# array(['Mississauga', 'Toronto', 'Newmarket', 'Etobicoke', 'Pickering',
#        'Richmond Hill', 'North York', 'Markham', 'Tottenham',
#        'Scarborough', 'Oakville', 'Brampton', 'Ajax', 'Thornhill',
#        'East York', 'Aurora', 'Maple', 'Vaughan', 'Bolton', 'Bradford',
#        'Mount Albert', 'Concord', 'Bradford West Gwillimbury', 'King',
#        'York', 'Kleinburg', 'Woodbridge', 'Brooklin', 'Whitby',
#        'Whitchurch-Stouffville', 'Georgetown', 'Stouffville',
#        'Halton Hills', 'THORNHILL', 'Beeton', 'King City', 'Schomberg',
#        'Thornhil', 'Missisauga', 'East Gwillimbury', 'North  York',
#        'Uxbridge', 'Caledon', 'Milton', 'Unionville', 'Rexdale',
#        'Caledon East', 'Nobleton', 'Thorncliffe Park', 'Port Credit',
#        'Agincourt', 'Clarkson', 'Oshawa', 'Malton', 'Sharon', 'Waterloo',
#        'Inglewood', 'Etobiicoke', 'Richmond Hil', 'Oak Ridges',
#        'Palgrave', 'Caledon Village', 'Bond Head', 'ETOBICOKE',
#        'New Tecumseth', 'Toronto Scarborough', 'Willowdale', 'Whiitby',
#        'River Drive Park', 'Etibicoke', 'Tornto', 'AGINCOURT',
#        'Centre Island', 'North Toronto', 'East Ajax', 'Scarobrough',
#        'Glen Williams', 'Whtiby', 'Goodwood', 'Holland Landing',
#        'Streetsville', 'Mississuaga', 'Oakridges',
#        'Regional Municipality of York', 'Don Mills'], dtype=object)

# %%
# Write csv or ontario restaurants only
yelp_restaurants_ontario_clean_csv_path = os.path.join('..', 'data', 'yelp_dataset', 'clean', 'restaurants.csv')
yelp_restaurants_ontario_clean.to_csv(yelp_restaurants_ontario_clean_csv_path)

# %%
# Create json file
yelp_restaurants_ontario_clean_json_path = os.path.join('..', 'data', 'yelp_dataset', 'clean', 'restaurants.json')
yelp_restaurants_ontario_clean.to_json(yelp_restaurants_ontario_clean_json_path, orient='index')
